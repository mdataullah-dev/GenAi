# %% [markdown]
# ### Stream LLM Responses in Real-Time like Chat-gpt!

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="openai/gpt-oss-120b", streaming=True)

question = "Can you explain me gen-ai in short"
response = llm.stream(question)

for chunks in response:
    print(chunks.content, end="")
# Out:
# Sure! Generative AI (often shortened to “gen‑AI”) refers to a class of artificial‑intelligence models that can **create new content**—such as text, images, audio, video, or code—rather than just analyzing or classifying existing data.
#
# **How it works (in a nutshell):**
# 1. **Training:** The model is fed massive amounts of data (e.g., books, pictures, code) and learns statistical patterns and relationships.
# 2. **Generation:** When you give it a prompt or a seed (like “Write a poem about sunrise”), the model samples from what it has learned to produce a plausible, original output that matches the prompt’s style and constraints.
#
# **Common types of generative models**
# - **Large Language Models (LLMs)** – e.g., GPT‑4, Claude, LLaMA, which generate text.
# - **Diffusion models** – e.g., Stable Diffusion, DALL‑E, Midjourney, which create images from text prompts.
# - **Generative Adversarial Networks (GANs)** – used for realistic image, video, or audio synthesis.
# - **Variational Autoencoders (VAEs)** – often used for generating music or 3D shapes.
#
# **Typical applications**
# - Writing assistance, code completion, chatbots.
# - Image creation and editing, design mock‑ups.
# - Music composition, voice cloning.
# - Synthetic data generation for training other AI systems.
#
# **Key points to keep in mind**
# - **Creativity vs. originality:** The output is novel but derived from patterns in the training data; it’s not truly “inventive” in the human sense.
# - **Bias & safety:** Because the model mirrors its training data, it can reproduce biases or generate harmful content, so responsible use and safeguards are essential.
# - **Prompt engineering:** The quality and relevance of the output often depend heavily on how you phrase the input prompt.
#
# In short, generative AI is about teaching machines to **produce** new, human‑like content by learning from huge datasets, opening up a wide range of creative and practical possibilities.
